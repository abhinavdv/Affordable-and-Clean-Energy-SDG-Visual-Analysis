# %%
import pandas as pd

# %%
import numpy as np
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
df = pd.read_excel("a4wdi.xlsx")

# %%
df.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.914625  17.392349  17.892005
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.473301   6.720331   7.015917
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                        Country Name Country Code  \
# 0       Africa Eastern and Southern          AFE
# 1       Africa Eastern and Southern          AFE
# 2       Africa Eastern and Southern          AFE
# 3       Africa Eastern and Southern          AFE
# 4       Africa Eastern and Southern          AFE
# ...                             ...          ...
# 392877                     Zimbabwe          ZWE
# 392878                     Zimbabwe          ZWE
# 392879                     Zimbabwe          ZWE
# 392880                     Zimbabwe          ZWE
# 392881                     Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 0       Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS
# 2       Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],
#       dtype='object')

# %%
print(df['Indicator Name'].unique())
# Out:
# ['Access to clean fuels and technologies for cooking (% of population)'
#  'Access to clean fuels and technologies for cooking, rural (% of rural population)'
#  'Access to clean fuels and technologies for cooking, urban (% of urban population)'
#  'Access to electricity (% of population)'
#  'Access to electricity, rural (% of rural population)'
#  'Access to electricity, urban (% of urban population)'
#  'Account ownership at a financial institution or with a mobile-money-service provider (% of population ages 15+)'
#  'Account ownership at a financial institution or with a mobile-money-service provider, female (% of population ages 15+)'
#  'Account ownership at a financial institution or with a mobile-money-service provider, male (% of population ages 15+)'
#  'Account ownership at a financial institution or with a mobile-money-service provider, older adults (% of population ages 25+)'
# ...

# %%
# Adjusted savings: net forest depletion (current US$)
# Adjusted savings: mineral depletion (current US$)
# Adjusted savings: energy depletion (current US$)
# Adjusted savings: natural resources depletion (% of GNI)
# Adjusted savings: net national savings (current US$)
# Adjusted net national income (current US$)
# Adjusted net national income (annual % growth)
# Adjusted net national income per capita (current US$)
# Adjusted net national income per capita (annual % growth)
# Adjusted net savings, including particulate emission damage (current US$)
# Adjusted net savings, excluding particulate emission damage (current US$)

# %%
df_adj_netNatIncomePerCapita = df.loc[df['Indicator Name'] == "Adjusted net national income per capita (current US$)"]

# %%
df_adj_netNatIncomePerCapita.head()
# Out:
#                         Country Name Country Code  \
# 27       Africa Eastern and Southern          AFE
# 1504      Africa Western and Central          AFW
# 2981                      Arab World          ARB
# 4458          Caribbean small states          CSS
# 5935  Central Europe and the Baltics          CEB
#
#                                          Indicator Name     Indicator Code  \
# 27    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 1504  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 2981  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 4458  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 5935  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
#
#       1960  1961  1962  1963  1964  1965  ...          2013          2014  \
# 27     NaN   NaN   NaN   NaN   NaN   NaN  ...   1296.804936   1310.864153
# ...

# %%
df_adj_netNatIncomePerCapita.describe
# Out:
# <bound method NDFrame.describe of                           Country Name Country Code  \
# 27         Africa Eastern and Southern          AFE
# 1504        Africa Western and Central          AFW
# 2981                        Arab World          ARB
# 4458            Caribbean small states          CSS
# 5935    Central Europe and the Baltics          CEB
# ...                                ...          ...
# 385524           Virgin Islands (U.S.)          VIR
# 387001              West Bank and Gaza          PSE
# 388478                     Yemen, Rep.          YEM
# 389955                          Zambia          ZMB
# 391432                        Zimbabwe          ZWE
#
#                                            Indicator Name     Indicator Code  \
# 27      Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 1504    Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# ...

# %%
df_pivot = pd.melt(df_adj_netNatIncomePerCapita,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],var_name='Year', value_name='indicator')

# %%
df_pivot.tail(100)
# Out:
#                 Country Name Country Code  \
# 16658       Macao SAR, China          MAC
# 16659             Madagascar          MDG
# 16660                 Malawi          MWI
# 16661               Malaysia          MYS
# 16662               Maldives          MDV
# ...                      ...          ...
# 16753  Virgin Islands (U.S.)          VIR
# 16754     West Bank and Gaza          PSE
# 16755            Yemen, Rep.          YEM
# 16756                 Zambia          ZMB
# 16757               Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 16658  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 16659  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 16660  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# 16661  Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# ...

# %%
df_pivot.dropna(subset=['indicator'],inplace=True)

# %%
df_pivot
# Out:
#                                       Country Name Country Code  \
# 2661                    Africa Western and Central          AFW
# 2665                    Early-demographic dividend          EAR
# 2666                           East Asia & Pacific          EAS
# 2667   East Asia & Pacific (excluding high income)          EAP
# 2668    East Asia & Pacific (IDA & IBRD countries)          TEA
# ...                                            ...          ...
# 16217                                   Uzbekistan          UZB
# 16218                                      Vanuatu          VUT
# 16220                                     Viet Nam          VNM
# 16224                                       Zambia          ZMB
# 16225                                     Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 2661   Adjusted net national income per capita (curre...  NY.ADJ.NNTY.PC.CD
# ...

# %%
df_pivot.to_csv("Adjusted net national income per capita A4.csv")

# %%
df_GDPperCapita = df.loc[df['Indicator Name'] == "GDP per capita (current US$)"]

# %%
df_GDPperCapita
# Out:
#                           Country Name Country Code  \
# 480        Africa Eastern and Southern          AFE
# 1957        Africa Western and Central          AFW
# 3434                        Arab World          ARB
# 4911            Caribbean small states          CSS
# 6388    Central Europe and the Baltics          CEB
# ...                                ...          ...
# 385977           Virgin Islands (U.S.)          VIR
# 387454              West Bank and Gaza          PSE
# 388931                     Yemen, Rep.          YEM
# 390408                          Zambia          ZMB
# 391885                        Zimbabwe          ZWE
#
#                       Indicator Name  Indicator Code        1960        1961  \
# 480     GDP per capita (current US$)  NY.GDP.PCAP.CD  161.638982  161.111657
# 1957    GDP per capita (current US$)  NY.GDP.PCAP.CD  107.423775  112.503866
# 3434    GDP per capita (current US$)  NY.GDP.PCAP.CD         NaN         NaN
# ...

# %%
df_pivot_GDP = pd.melt(df_GDPperCapita,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],var_name='Year', value_name='GDP_per_captia')

# %%
df_pivot_GDP
# Out:
#                          Country Name Country Code  \
# 0         Africa Eastern and Southern          AFE
# 1          Africa Western and Central          AFW
# 2                          Arab World          ARB
# 3              Caribbean small states          CSS
# 4      Central Europe and the Baltics          CEB
# ...                               ...          ...
# 16753           Virgin Islands (U.S.)          VIR
# 16754              West Bank and Gaza          PSE
# 16755                     Yemen, Rep.          YEM
# 16756                          Zambia          ZMB
# 16757                        Zimbabwe          ZWE
#
#                      Indicator Name  Indicator Code  Year  GDP_per_captia
# 0      GDP per capita (current US$)  NY.GDP.PCAP.CD  1960      161.638982
# 1      GDP per capita (current US$)  NY.GDP.PCAP.CD  1960      107.423775
# 2      GDP per capita (current US$)  NY.GDP.PCAP.CD  1960             NaN
# ...

# %%
df_pivot_GDP.dropna(subset=['GDP_per_captia'],inplace=True)

# %%
df_pivot_GDP
# Out:
#                       Country Name Country Code                Indicator Name  \
# 0      Africa Eastern and Southern          AFE  GDP per capita (current US$)
# 1       Africa Western and Central          AFW  GDP per capita (current US$)
# 3           Caribbean small states          CSS  GDP per capita (current US$)
# 5       Early-demographic dividend          EAR  GDP per capita (current US$)
# 6              East Asia & Pacific          EAS  GDP per capita (current US$)
# ...                            ...          ...                           ...
# 16752                     Viet Nam          VNM  GDP per capita (current US$)
# 16754           West Bank and Gaza          PSE  GDP per capita (current US$)
# 16755                  Yemen, Rep.          YEM  GDP per capita (current US$)
# 16756                       Zambia          ZMB  GDP per capita (current US$)
# 16757                     Zimbabwe          ZWE  GDP per capita (current US$)
#
# ...

# %%
df_pivot_GDP.to_csv("GDP per capita A4.csv")

# %%
#EG.ELC.ACCS.ZS #access to electricity %ge population
#EN.ATM.CO2E.PC #CO2 emissions (metric tons per capita

# %%
df_elec_co2 = df_adj_netNatIncomePerCapita = df.loc[(df['Indicator Code'] == "EG.ELC.ACCS.ZS") | (df['Indicator Code'] == "EN.ATM.CO2E.PC")]

# %%
df_elec_co2
# Out:
#                        Country Name Country Code  \
# 3       Africa Eastern and Southern          AFE
# 193     Africa Eastern and Southern          AFE
# 1480     Africa Western and Central          AFW
# 1670     Africa Western and Central          AFW
# 2957                     Arab World          ARB
# ...                             ...          ...
# 388644                  Yemen, Rep.          YEM
# 389931                       Zambia          ZMB
# 390121                       Zambia          ZMB
# 391408                     Zimbabwe          ZWE
# 391598                     Zimbabwe          ZWE
#
#                                  Indicator Name  Indicator Code  1960  1961  \
# 3       Access to electricity (% of population)  EG.ELC.ACCS.ZS   NaN   NaN
# 193      CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC   NaN   NaN
# 1480    Access to electricity (% of population)  EG.ELC.ACCS.ZS   NaN   NaN
# ...

# %%
df_elec_co2_pivot = pd.melt(df_elec_co2,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],var_name='Year', value_name='indicator')
df_elec_co2_pivot.dropna(subset=['indicator'],inplace=True)

# %%
df_elec_co2_pivot["Year"] = df_elec_co2_pivot["Year"].astype(int)

# %%
#only need from 2000 to 2020
df_elec_co2_pivot["Year"] = df_elec_co2_pivot["Year"].astype(int)
df_elec_co2_pivot_20_22 = df_elec_co2_pivot.loc[df_elec_co2_pivot['Year'] >= 2000]
df_elec_co2_pivot_20_2020 = df_elec_co2_pivot_20_22.loc[df_elec_co2_pivot_20_22['Year'] <= 2020]

# %%
df_elec_co2_pivot_20_2020
# Out:
#                       Country Name Country Code  \
# 21280  Africa Eastern and Southern          AFE
# 21281  Africa Eastern and Southern          AFE
# 21282   Africa Western and Central          AFW
# 21283   Africa Western and Central          AFW
# 21284                   Arab World          ARB
# ...                            ...          ...
# 32447                  Yemen, Rep.          YEM
# 32448                       Zambia          ZMB
# 32449                       Zambia          ZMB
# 32450                     Zimbabwe          ZWE
# 32451                     Zimbabwe          ZWE
#
#                                 Indicator Name  Indicator Code  Year  \
# 21280  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000
# 21281   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2000
# 21282  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000
# 21283   CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2000
# ...

# %%
df_elec_co2_pivot_20_2020.to_csv("electricity and CO2 data 2000-2020.csv")

# %%
df_elec = df_elec_co2_pivot_20_2020.loc[df_elec_co2_pivot_20_2020["Indicator Code"]=="EG.ELC.ACCS.ZS"]

# %%
df_co2 = df_elec_co2_pivot_20_2020.loc[df_elec_co2_pivot_20_2020["Indicator Code"]=="EN.ATM.CO2E.PC"]

# %%
df_elec
# Out:
#                          Country Name Country Code  \
# 21280     Africa Eastern and Southern          AFE
# 21282      Africa Western and Central          AFW
# 21284                      Arab World          ARB
# 21286          Caribbean small states          CSS
# 21288  Central Europe and the Baltics          CEB
# ...                               ...          ...
# 32442           Virgin Islands (U.S.)          VIR
# 32444              West Bank and Gaza          PSE
# 32446                     Yemen, Rep.          YEM
# 32448                          Zambia          ZMB
# 32450                        Zimbabwe          ZWE
#
#                                 Indicator Name  Indicator Code  Year  \
# 21280  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000
# 21282  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000
# 21284  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000
# 21286  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000
# ...

# %%
df_co2
# Out:
#                          Country Name Country Code  \
# 21281     Africa Eastern and Southern          AFE
# 21283      Africa Western and Central          AFW
# 21285                      Arab World          ARB
# 21287          Caribbean small states          CSS
# 21289  Central Europe and the Baltics          CEB
# ...                               ...          ...
# 32439                   Venezuela, RB          VEN
# 32441                        Viet Nam          VNM
# 32447                     Yemen, Rep.          YEM
# 32449                          Zambia          ZMB
# 32451                        Zimbabwe          ZWE
#
#                                Indicator Name  Indicator Code  Year  indicator
# 21281  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2000   0.891352
# 21283  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2000   0.521689
# 21285  CO2 emissions (metric tons per capita)  EN.ATM.CO2E.PC  2000   3.253567
# ...

# %%
result = pd.concat([df_elec, df_co2], axis=1).reindex(df_elec.index)

# %%
result
# Out:
#                          Country Name Country Code  \
# 21280     Africa Eastern and Southern          AFE
# 21282      Africa Western and Central          AFW
# 21284                      Arab World          ARB
# 21286          Caribbean small states          CSS
# 21288  Central Europe and the Baltics          CEB
# ...                               ...          ...
# 32442           Virgin Islands (U.S.)          VIR
# 32444              West Bank and Gaza          PSE
# 32446                     Yemen, Rep.          YEM
# 32448                          Zambia          ZMB
# 32450                        Zimbabwe          ZWE
#
#                                 Indicator Name  Indicator Code    Year  \
# 21280  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000.0
# 21282  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000.0
# 21284  Access to electricity (% of population)  EG.ELC.ACCS.ZS  2000.0
# ...

# %%
df_co2.to_csv("CO2 2000-2020.csv")
df_elec.to_csv("elec 2000-2022.csv")

# %%
df_greenhouse = df.loc[(df['Indicator Code'] == "EN.ATM.GHGT.KT.CE")]

# %%
df_greenhouse_pivot = pd.melt(df_greenhouse,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],var_name='Year', value_name='indicator')
df_greenhouse_pivot.dropna(subset=['indicator'],inplace=True)

# %%
df_greenhouse_pivot
# Out:
#                          Country Name Country Code  \
# 7980      Africa Eastern and Southern          AFE
# 7981       Africa Western and Central          AFW
# 7982                       Arab World          ARB
# 7983           Caribbean small states          CSS
# 7984   Central Europe and the Baltics          CEB
# ...                               ...          ...
# 16219                   Venezuela, RB          VEN
# 16220                        Viet Nam          VNM
# 16223                     Yemen, Rep.          YEM
# 16224                          Zambia          ZMB
# 16225                        Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 7980   Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE
# 7981   Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE
# 7982   Total greenhouse gas emissions (kt of CO2 equi...  EN.ATM.GHGT.KT.CE
# ...

# %%
df_greenhouse_pivot["Year"] = df_greenhouse_pivot["Year"].astype(int)
df_greenhouse_pivot_20_22 = df_greenhouse_pivot.loc[df_greenhouse_pivot['Year'] >= 2000]
df_greenhouse_pivot_20_2020 = df_greenhouse_pivot_20_22.loc[df_greenhouse_pivot_20_22['Year'] <= 2020]

# %%
df_greenhouse_pivot_20_2020.to_csv("greenhouse 2020-2022.csv")

# %%
df2 = pd.read_csv("per capita greenhouse emission.csv")

# %%
df2['Indicator Name'] = 'Greenhouse emission per capita'

# %%
df2
# Out:
#                                    Country Name Country Code  \
# 0                                   Afghanistan          AFG
# 1                                       Albania          ALB
# 2                                       Algeria          DZA
# 3                                American Samoa          ASM
# 4                                       Andorra          AND
# ..                                          ...          ...
# 261                          Sub-Saharan Africa          SSF
# 262  Sub-Saharan Africa (excluding high income)          SSA
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 264                         Upper middle income          UMC
# 265                                       World          WLD
#
#                  2000              2001              2002              2003  \
# 0    726.876035090244   640.20495431069  726.438455321687  704.832902261987
# 1    2642.89615532658  2654.37179401295  2870.99793543777  3015.94518024645
# ...

# %%
df_green_per_capita = pd.melt(df2,id_vars=['Country Name', 'Country Code', 'Indicator Name'], value_vars=['2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020'],var_name='Year', value_name='indicator')

# %%
df_green_per_capita.to_csv("greenhouse per capita12.csv")

# %%
df_green_per_capita
# Out:
#                                     Country Name Country Code  \
# 0                                    Afghanistan          AFG
# 1                                        Albania          ALB
# 2                                        Algeria          DZA
# 3                                 American Samoa          ASM
# 4                                        Andorra          AND
# ...                                          ...          ...
# 5581                          Sub-Saharan Africa          SSF
# 5582  Sub-Saharan Africa (excluding high income)          SSA
# 5583   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 5584                         Upper middle income          UMC
# 5585                                       World          WLD
#
#                       Indicator Name  Year         indicator
# 0     Greenhouse emission per capita  2000  726.876035090244
# 1     Greenhouse emission per capita  2000  2642.89615532658
# ...

# %%
#pick required indicator/s
df_new = df.loc[df['Indicator Code'] == "SP.POP.TOTL"]
#pivot to get years
df_pivot_1 = pd.melt(df_new,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],var_name='Year', value_name='indicator')
#remove null values
df_pivot_1.dropna(subset=['indicator'],inplace=True)
#filter for required time
df_pivot_1["Year"] = df_pivot_1["Year"].astype(int)
df_pivot_1_20_22 = df_pivot_1.loc[df_pivot_1['Year'] >= 2000]
df_pivot_1_20_2020 = df_pivot_1_20_22.loc[df_pivot_1_20_22['Year'] <= 2020]
#check once
df_pivot_1_20_2020
# Out:
#                          Country Name Country Code     Indicator Name  \
# 10640     Africa Eastern and Southern          AFE  Population, total
# 10641      Africa Western and Central          AFW  Population, total
# 10642                      Arab World          ARB  Population, total
# 10643          Caribbean small states          CSS  Population, total
# 10644  Central Europe and the Baltics          CEB  Population, total
# ...                               ...          ...                ...
# 16221           Virgin Islands (U.S.)          VIR  Population, total
# 16222              West Bank and Gaza          PSE  Population, total
# 16223                     Yemen, Rep.          YEM  Population, total
# 16224                          Zambia          ZMB  Population, total
# 16225                        Zimbabwe          ZWE  Population, total
#
#       Indicator Code  Year    indicator
# 10640    SP.POP.TOTL  2000  401600588.0
# 10641    SP.POP.TOTL  2000  269611898.0
# ...

# %%
#extract as CSV
df_pivot_1_20_2020.to_csv("population.csv")

# %%
#EG.ELC.ACCS.RU.ZS  Access to electricity, rural (% of rural population)
#EG.ELC.ACCS.UR.ZS Access to electricity, urban (% of urban population)

# %%
#pick required indicator/s
df_new = df.loc[df['Indicator Code'] == "EG.ELC.ACCS.RU.ZS"]
#pivot to get years
df_pivot_1 = pd.melt(df_new,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],var_name='Year', value_name='indicator')
#remove null values
df_pivot_1.dropna(subset=['indicator'],inplace=True)
#filter for required time
df_pivot_1["Year"] = df_pivot_1["Year"].astype(int)
df_pivot_1_20_22 = df_pivot_1.loc[df_pivot_1['Year'] >= 2000]
df_pivot_1_20_2020 = df_pivot_1_20_22.loc[df_pivot_1_20_22['Year'] <= 2020]
#check once
df_pivot_1_20_2020
# Out:
#                          Country Name Country Code  \
# 10640     Africa Eastern and Southern          AFE
# 10641      Africa Western and Central          AFW
# 10642                      Arab World          ARB
# 10643          Caribbean small states          CSS
# 10644  Central Europe and the Baltics          CEB
# ...                               ...          ...
# 16221           Virgin Islands (U.S.)          VIR
# 16222              West Bank and Gaza          PSE
# 16223                     Yemen, Rep.          YEM
# 16224                          Zambia          ZMB
# 16225                        Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 10640  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 10641  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# 10642  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS
# ...

# %%
df_pivot_1_20_2020.to_csv("rural_electricity.csv")

# %%
#pick required indicator/s
df_new = df.loc[df['Indicator Code'] == "EG.ELC.ACCS.UR.ZS"]
#pivot to get years
df_pivot_1 = pd.melt(df_new,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],var_name='Year', value_name='indicator')
#remove null values
df_pivot_1.dropna(subset=['indicator'],inplace=True)
#filter for required time
df_pivot_1["Year"] = df_pivot_1["Year"].astype(int)
df_pivot_1_20_22 = df_pivot_1.loc[df_pivot_1['Year'] >= 2000]
df_pivot_1_20_2020 = df_pivot_1_20_22.loc[df_pivot_1_20_22['Year'] <= 2020]
#check once
df_pivot_1_20_2020
# Out:
#                          Country Name Country Code  \
# 10640     Africa Eastern and Southern          AFE
# 10641      Africa Western and Central          AFW
# 10642                      Arab World          ARB
# 10643          Caribbean small states          CSS
# 10644  Central Europe and the Baltics          CEB
# ...                               ...          ...
# 16221           Virgin Islands (U.S.)          VIR
# 16222              West Bank and Gaza          PSE
# 16223                     Yemen, Rep.          YEM
# 16224                          Zambia          ZMB
# 16225                        Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 10640  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 10641  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# 10642  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS
# ...

# %%
df_pivot_1_20_2020.to_csv("urban_electricity.csv")

# %%
#Renewable Energy Consumption (% Of Total Final Energy Consumption)

# %%
#pick required indicator/s
df_new = df.loc[df['Indicator Code'] == "EG.FEC.RNEW.ZS"]
#pivot to get years
df_pivot_1 = pd.melt(df_new,id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], value_vars=['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022'],var_name='Year', value_name='indicator')
#remove null values
df_pivot_1.dropna(subset=['indicator'],inplace=True)
#filter for required time
df_pivot_1["Year"] = df_pivot_1["Year"].astype(int)
df_pivot_1_20_22 = df_pivot_1.loc[df_pivot_1['Year'] >= 2000]
df_pivot_1_20_2020 = df_pivot_1_20_22.loc[df_pivot_1_20_22['Year'] <= 2020]
#check once
df_pivot_1_20_2020
# Out:
#                          Country Name Country Code  \
# 10640     Africa Eastern and Southern          AFE
# 10641      Africa Western and Central          AFW
# 10642                      Arab World          ARB
# 10643          Caribbean small states          CSS
# 10644  Central Europe and the Baltics          CEB
# ...                               ...          ...
# 16221           Virgin Islands (U.S.)          VIR
# 16222              West Bank and Gaza          PSE
# 16223                     Yemen, Rep.          YEM
# 16224                          Zambia          ZMB
# 16225                        Zimbabwe          ZWE
#
#                                           Indicator Name  Indicator Code  \
# 10640  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 10641  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# 10642  Renewable energy consumption (% of total final...  EG.FEC.RNEW.ZS
# ...

# %%
df_pivot_1_20_2020.to_csv("renewable electricity output.csv")
